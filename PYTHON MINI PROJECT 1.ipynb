# %%
import os

# List to hold the dictionaries (empty books library)
library = []

# Function to add a book
def add_book(title, author, genre, year, status="unread"):
    book = {
        "title": title.strip(),
        "author": author.strip(),
        "genre": genre.strip(),
        "year": int(year),
        "status": status.lower().strip()
    }
    library.append(book)
    print(f"Book '{title}' added.")

# Function to list books
def list_books(sorted_by_year=False):
    if not library:
        print("Library is empty.")
        return
    books = sorted(library, key=lambda x: x['year']) if sorted_by_year else library
    for idx, book in enumerate(books, start=1):
        print(f"{idx}. {book['title']} by {book['author']} [{book['genre']}, {book['year']}] - {book['status'].capitalize()}")

# Function to search by author
def search_by_author(author_name):
    return [book for book in library if author_name.lower() in book['author'].lower()]

# Function to delete a book by title
def delete_book(title):
    removed = False
    for i in range(len(library)-1, -1, -1):  # Iterate backwards to delete safely
        if library[i]['title'].lower() == title.lower():
            del library[i]
            removed = True
    if removed:
        print(f"Book titled '{title}' has been removed.")
    else:
        print(f"No book titled '{title}' found.")

# Show reading summary
def show_reading_summary():
    if not library:
        print("No books in library.")
        return
    read = len([x for x in library if x['status'] == 'read'])
    unread = len(library) - read
    print(f"Read: {read} books ({(read/len(library))*100:.2f}%)")
    print(f"Unread: {unread} books ({(unread/len(library))*100:.2f}%)")

# Convert titles of the books to uppercase
def uppercase_titles():
    titles = [b['title'].upper() for b in library]
    print("Book Titles (UPPERCASE):")
    for title in titles:
        print("-", title)

# Function to save library of books to a file
def save_to_file(filename):
    try:
        with open(filename, 'w') as f:
            for book in library:
                line = f"{book['title']},{book['author']},{book['genre']},{book['year']},{book['status']}\n"
                f.write(line)
        print(f"Saved {len(library)} books to {filename}")
    except Exception as e:
        print("Error saving file:", e)

# Loading book data from a file
def load_from_file(filename):
    if not os.path.exists(filename):
        print("File not found. Starting with an empty library.")
        return
    try:
        with open(filename, 'r') as f:
            for line in f:
                if line.strip():  # Avoid empty lines
                    title, author, genre, year, status = line.strip().split(',')
                    add_book(title, author, genre, int(year), status)
        print("Library loaded successfully.")
    except Exception as e:
        print("Error reading file:", e)

# Menu function for your library app
def menu():
    while True:
        print("\n--- Personal Library Menu ---")
        print("1. Add Book")
        print("2. List All Books")
        print("3. List Books Sorted by Year")
        print("4. Search by Author")
        print("5. Delete Book by Title")
        print("6. Show Reading Summary")
        print("7. Show UPPERCASE Book Titles (map)")
        print("8. Save Library")
        print("9. Load Library")
        print("10. Exit")
        choice = input("Choose an option: ")

        if choice == "1":
            title = input("Title: ")
            author = input("Author: ")
            genre = input("Genre: ")
            year = input("Year: ")
            status = input("Status (read/unread): ")
            add_book(title, author, genre, year, status)
        elif choice == "2":
            list_books()
        elif choice == "3":
            list_books(sorted_by_year=True)
        elif choice == "4":
            author = input("Enter author name: ")
            results = search_by_author(author)
            print(f"\nFound {len(results)} books by {author}:")
            for book in results:
                print(f"- {book['title']} ({book['year']})")
        elif choice == "5":
            title = input("Enter title to delete: ")
            delete_book(title)
        elif choice == "6":
            show_reading_summary()
        elif choice == "7":
            uppercase_titles()
        elif choice == "8":
            save_to_file("books_data.txt")
        elif choice == "9":
            load_from_file("books_data.txt")
        elif choice == "10":
            print("Goodbye!")
            break
        else:
            print("Invalid option. Try again.")

# Run the menu if this script is executed directly
if __name__ == "__main__":
    menu()
# Out:
# --- Personal Library Menu ---
# 1. Add Book
# 2. List All Books
# 3. List Books Sorted by Year
# 4. Search by Author
# 5. Delete Book by Title
# 6. Show Reading Summary
# 7. Show UPPERCASE Book Titles (map)
# 8. Save Library
# 9. Load Library
# 10. Exit
# Choose an option:  1
# Title:  ram the travellar
# Author:  kishore
# Genre:  ram
# Year:  2026
# Status (read/unread):
# Book 'ram the travellar' added.
#
# --- Personal Library Menu ---
# 1. Add Book
# 2. List All Books
# 3. List Books Sorted by Year
# 4. Search by Author
# 5. Delete Book by Title
# 6. Show Reading Summary
# 7. Show UPPERCASE Book Titles (map)
# 8. Save Library
# 9. Load Library
# 10. Exit
# Choose an option:  2
# 1. ram the travellar by kishore [ram, 2026] -
#
# --- Personal Library Menu ---
# 1. Add Book
# 2. List All Books
# 3. List Books Sorted by Year
# 4. Search by Author
# 5. Delete Book by Title
# 6. Show Reading Summary
# 7. Show UPPERCASE Book Titles (map)
# 8. Save Library
# 9. Load Library
# 10. Exit
# Choose an option:  4
# Enter author name:  kishore
# Found 1 books by kishore:
# - ram the travellar (2026)
#
# --- Personal Library Menu ---
# 1. Add Book
# 2. List All Books
# 3. List Books Sorted by Year
# 4. Search by Author
# 5. Delete Book by Title
# 6. Show Reading Summary
# 7. Show UPPERCASE Book Titles (map)
# 8. Save Library
# 9. Load Library
# 10. Exit
